# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./mtcars.csv')
df.head()
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp     hp  drat     wt   qsec  vs  \
# 0     1          Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0
# 2     3         Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1
# 4     5  Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02   0
#
#    am  gear  carb
# 0   1     4     4
# 1   1     4     4
# 2   1     4     1
# 3   0     3     1
# 4   0     3     2

# %%
df.shape
# Out:
# (32, 13)

# %%
# bar plot -> 
res = sns.barplot(df['cyl'], df['mpg'])
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
res = sns.barplot(x=df['cyl'], y=df['mpg'], )
plt.show()

# %%
# res = sns.barplot(x='cyl', y='mpg',  data=df)
# res = sns.barplot(x='cyl', y='wt',  data=df)
plt.show()

# %%
# res = sns.barplot(x='cyl', y='mpg',  data=df, color='red')
res = sns.barplot(x='cyl', y='mpg',  data=df, color='green')
plt.show()

# %%
res = sns.barplot(x='cyl', y='mpg',  data=df, palette='Set2')
plt.show()

# %%
res = sns.barplot(x='cyl', y='mpg',  data=df, palette='Set1')
plt.show()

# %%
sns.barplot(x='gear', y='hp',  data=df, palette='Set2')
plt.show()

# %%
# count plot
sns.countplot(x='cyl', data=df, palette='Set2')
plt.show()

# %%
sns.countplot(x='gear', data=df, palette='Set2')
plt.show()

# %%
sns.countplot(y='gear', data=df, palette='Set2')
plt.show()

# %%
# sns.countplot(x='gear', y='cyl', data=df, palette='Set2') # error
# hue
sns.countplot(x='gear', hue='cyl', data=df, palette='Set2')
plt.show()

# %%
sns.countplot(x='cyl', hue='gear', data=df, palette='Set2')
plt.show()

# %%
# heatmap
# sns.heatmap(df.corr(), cbar=False, linewidths=0.5)
# plt.show()

# sns.heatmap(df.corr(), cbar=True, linewidths=0.5)
# plt.show()

# sns.heatmap(df.corr(), cbar=True, linewidths=0.5)
# plt.show()

# %%
# scatterplot
sns.scatterplot(x='disp', y='hp', data=df)
# Out:
# <AxesSubplot:xlabel='disp', ylabel='hp'>

# %%
# mileage
sns.scatterplot(x='disp', y='hp', data=df, hue='mpg')
plt.show()

# %%
# pairplot
sns.pairplot(df)

# %%
sns.pairplot(df, hue='mpg', palette='Set1')
