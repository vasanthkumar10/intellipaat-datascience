# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.4.2

# %%
# 3 data structures
# 1. Series -> 1d array -> list
# 2. Dataframe -> 2d -> dictionary, list, series or dataframe
# 3. Panel -> multi dimensional

# series
# pd.Series(['1', '2', '3' ])
# pd.Series(['vasi', 'raj', 'deepak'], index=['a', 'b', 'c'])
# data = pd.Series(['vasi', 'raj', 'deepak'], index=['a', 'b', 'c'])
# print(data['a'])

# person = {
#     'name': 'vasi',
#     'age': 29,
#     'ages': [1, 2, 3]
# }
# data = pd.Series(person)
# data
# data['name']
# data['age']
# data['ages']
# Out:
# [1, 2, 3]

# %%
# ways to create the dataset
person = {
    'cars': ['mercedez', 'audi'],
    'bike': ['honda', 'RE']
}
pd.DataFrame(person)
# Out:
#        cars   bike
# 0  mercedez  honda
# 1      audi     RE

# %%
pd.read_csv('mtcars.csv')
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
# pd.read_excel('somecars1.xlsx')

# %%
df = pd.read_csv('mtcars.csv')
#check the type
# type(df)
# df.shape
# df.ndim
# df
# print(df.head())
# print(df.head(3))
# print(df.head(-30))
# print(df.tail())
# print(df.tail(3))
# print(df.tail(-3))
# Out:
# 70.30952911986732

# %%
# read data

# columns
# print(df.columns, type(df.columns))
# print(df['name'])
# print(df.name)
# print(df['name'][0])
# print(df[['name', 'hp', 'mpg']])



# rows
# print(df.head())
# print(df.iloc[0]) #initial location
# print(df.iloc[1:4])
# print(df.iloc[1:4:2])
# print(df.iloc[-1])
# print(df.iloc[-4:-1])
# print(df.iloc[-4:-1:2])
# print(df.iloc[::-1])



# specific location
# print(df.iloc[2,1])
# print(df.iloc[2:5, 3:9])


#see all the record of mpg column
# df.loc[:,"mpg"]
# df.loc[:, 'mpg': "qsec"]


# change index
# print(df.index)
# df.set_index('hp')
# df.set_index('hp', inplace=True)
df.reset_index(inplace=True)
df
# Out:
#      hp  S.No           Unnamed: 1   mpg  cyl   disp  drat     wt   qsec  vs  \
# 0   110     1            Mazda RX4  21.0    6  160.0  3.90  2.620  16.46   0
# 1   110     2        Mazda RX4 Wag  21.0    6  160.0  3.90  2.875  17.02   0
# 2    93     3           Datsun 710  22.8    4  108.0  3.85  2.320  18.61   1
# 3   110     4       Hornet 4 Drive  21.4    6  258.0  3.08  3.215  19.44   1
# 4   175     5    Hornet Sportabout  18.7    8  360.0  3.15  3.440  17.02   0
# 5   105     6              Valiant  18.1    6  225.0  2.76  3.460    NaN   1
# 6   245     7           Duster 360  14.3    8  360.0  3.21  3.570  15.84   0
# 7    62     8            Merc 240D  24.4    4  146.7  3.69  3.190  20.00   1
# 8    95     9             Merc 230  22.8    4  140.8  3.92  3.150  22.90   1
# 9   123    10             Merc 280  19.2    6  167.6  3.92  3.440  18.30   1
# 10  123    11            Merc 280C  17.8    6  167.6  3.92  3.440  18.90   1
# ...

# %%
# print(df['hp'].mean())
# print(df['hp'].median())

# df['hp'].std()
df['hp'].max()
df['hp'].min()
df['hp'].count()

# describing the data
# df.describe()

# sorting
# df.sort_values('name')
# DataFrame.sort_values(by, *, axis=0, ascending=True, 
#                       inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)[source]
# df.sort_values('cyl')
# df.sort_values(['cyl', 'disp'], ascending=False)
# df.sort_values(['cyl', 'disp'], ascending=[False ,True])
# Out:
# 30

# %%
# rename
# df = df.rename(columns={'Unnamed: 1':'model'})
# df

# make changes
# df['power'] = df['hp'] * df['gear']
# print(df)

# drop_column
# df = df.drop(columns=['power', 'vs'])
df = df.drop(columns=['S.No'])
# df.head(3)
df
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76  3.460    NaN   1   0
# 6            Duster 360  14.3    8  360.0  245.0  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95.0  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123.0  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123.0  3.92  3.440  18.90   1   0
# ...

# %%
# to save in new csv
df.to_csv('new_csv.csv')

# %%
df.fillna(0)
# Out:
#      hp  S.No           Unnamed: 1   mpg  cyl   disp  drat     wt   qsec  vs  \
# 0   110     1            Mazda RX4  21.0    6  160.0  3.90  2.620  16.46   0
# 1   110     2        Mazda RX4 Wag  21.0    6  160.0  3.90  2.875  17.02   0
# 2    93     3           Datsun 710  22.8    4  108.0  3.85  2.320  18.61   1
# 3   110     4       Hornet 4 Drive  21.4    6  258.0  3.08  3.215  19.44   1
# 4   175     5    Hornet Sportabout  18.7    8  360.0  3.15  3.440  17.02   0
# 5   105     6              Valiant  18.1    6  225.0  2.76  3.460   0.00   1
# 6   245     7           Duster 360  14.3    8  360.0  3.21  3.570  15.84   0
# 7    62     8            Merc 240D  24.4    4  146.7  3.69  3.190  20.00   1
# 8    95     9             Merc 230  22.8    4  140.8  3.92  3.150  22.90   1
# 9   123    10             Merc 280  19.2    6  167.6  3.92  3.440  18.30   1
# 10  123    11            Merc 280C  17.8    6  167.6  3.92  3.440  18.90   1
# ...

# %%
df = pd.read_csv('mtcars.csv')
# df = df.fillna({
#     'Unnamed: 1': 'no-name',
#     'disp': 100
# })
# df = df.fillna(method="ffill")
# df = df.fillna(method="ffill", limit = 1)
# df = df.fillna(method="ffill", limit = 10)
# df = df.fillna(method="bfill")
# df = df.fillna(method="bfill", limit = 1)
# df = df.fillna(method="bfill", limit = 10)

df = df.interpolate()
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl    disp     hp  drat     wt    qsec  \
# 0      1            Mazda RX4  21.0    6  160.00  110.0  3.90  2.620  16.460
# 1      2        Mazda RX4 Wag  21.0    6  160.00  110.0  3.90  2.875  17.020
# 2      3           Datsun 710  22.8    4  108.00   93.0  3.85  2.320  18.610
# 3      4       Hornet 4 Drive  21.4    6  258.00  110.0  3.08  3.215  19.440
# 4      5    Hornet Sportabout  18.7    8  360.00  175.0  3.15  3.440  17.020
# 5      6              Valiant  18.1    6  225.00  105.0  2.76  3.460  16.430
# 6      7           Duster 360  14.3    8  360.00  245.0  3.21  3.570  15.840
# 7      8            Merc 240D  24.4    4  146.70   62.0  3.69  3.190  20.000
# 8      9             Merc 230  22.8    4  140.80   95.0  3.92  3.150  22.900
# 9     10             Merc 280  19.2    6  167.60  123.0  3.92  3.440  18.300
# 10    11            Merc 280C  17.8    6  167.60  123.0  3.92  3.440  18.900
# ...

# %%
# drop na
df = pd.read_csv('mtcars.csv')
df
# new_df = df.dropna()
# new_df = df.dropna(how="all")
# new_df = df.dropna(thresh=1)
# new_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp     hp  drat     wt   qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02
# 2      3           Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61
# 3      4       Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44
# 4      5    Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02
# 5      6              Valiant  18.1    6  225.0  105.0  2.76  3.460    NaN
# 6      7           Duster 360  14.3    8  360.0  245.0  3.21  3.570  15.84
# 7      8            Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00
# 8      9             Merc 230  22.8    4  140.8   95.0  3.92  3.150  22.90
# 9     10             Merc 280  19.2    6  167.6  123.0  3.92  3.440  18.30
# 10    11            Merc 280C  17.8    6  167.6  123.0  3.92  3.440  18.90
# ...

# %%
df = pd.read_csv('mtcars.csv')
import numpy as np
# new_df = df.replace(0, np.NaN)
# new_df = df.replace([0, 1], np.NaN)
new_df = df.replace({
    'vs': 0,
    "am": 1
}, np.NaN)
new_df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp     hp  drat     wt   qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02
# 2      3           Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61
# 3      4       Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44
# 4      5    Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02
# 5      6              Valiant  18.1    6  225.0  105.0  2.76  3.460    NaN
# 6      7           Duster 360  14.3    8  360.0  245.0  3.21  3.570  15.84
# 7      8            Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00
# 8      9             Merc 230  22.8    4  140.8   95.0  3.92  3.150  22.90
# 9     10             Merc 280  19.2    6  167.6  123.0  3.92  3.440  18.30
# 10    11            Merc 280C  17.8    6  167.6  123.0  3.92  3.440  18.90
# ...

# %%
# f = lambda x: x*4
def double(num):
    return num*4

df['am']= df['am'].apply(f)
df
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0  32
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0  32
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1  32
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76  3.460    NaN   1   0
# 6            Duster 360  14.3    8  360.0  245.0  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95.0  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123.0  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123.0  3.92  3.440  18.90   1   0
# ...

# %%
# filtering
# print(cars['name'][cars['hp'] < 100])

# df['cyl'] > 6
#filter records with more than 6 cylinders
filter1 = df['cyl'] > 6
# filter1
#apply filter to dataframe
filtered_new = df[filter1]
#view filtered dataframe
filtered_new
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 4     Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02   0   0
# 6            Duster 360  14.3    8  360.0  245.0  3.21  3.570  15.84   0   0
# 11           Merc 450SE  16.4    8  275.8    NaN  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180.0  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8    NaN    NaN  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8    NaN  205.0  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8    NaN  215.0  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8    NaN  230.0  3.23  5.345  17.42   0   0
# 21     Dodge Challenger  15.5    8  318.0  150.0  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150.0  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245.0  3.73  3.840  15.41   0   0
# ...

# %%
# Joins
A = pd.DataFrame({
    'color': ['green', 'yellow', 'red'],
    'num': [1, 2, 3]
})

B = pd.DataFrame({
    'color': ['yellow', 'green', 'pink'],
    'size': ['s', 'm', 'l']
})

# %%
# pd.merge(A, B, on='color')
# pd.merge(A, B)
# pd.merge(A, B, how='inner')
# pd.merge(A, B, how='outer')
# pd.merge(A, B, how='left')
# pd.merge(A, B, how='right')

# %%
A = pd.DataFrame({
    'colors': ['green', 'yellow', 'red'],
    'num': [1, 2, 3]
})

B = pd.DataFrame({
    't-shirt': ['yellow', 'green', 'pink'],
    'size': ['s', 'm', 'l']
})

# pd.merge(A, B, left_on='colors', right_on='t-shirt')
